_7": 114, "8_5_4": 115, "5_15_7": 116, "5_14": 117, "5_21": 118, "1_1": 119, "6_15_1": 120, "8_6_4": 121, "8_15": 122, "4_5": 123, "3_11": 124, "8_18": 125, "8_4_4": 126, "3_30": 127, "5_7_1": 128, "5_7_2": 129, "1_5": 130, "3_29": 131, "6_15_3": 132, "5_12": 133, "3_16": 134, "1_30": 135, "5_11": 136, "1_6": 137, "8_6_2": 138, "6_8_3": 139, "3_12": 140, "3_33": 141, "8_4_3": 142, "5_8": 143, "8_14": 144, "8_17": 145, "3_6": 146, "1_26": 147, "8_5_2": 148, "6_8_1": 149, "5_17": 150, "1_10": 151, "8_16": 152, "7_18": 153, "7_14": 154, "8_23": 155}
sings_rtsd = dict(zip(range(len(sings_rtsd)), [x.replace('_','.') for x in list(sings_rtsd.keys())]))

# %%
sings_input = ['3.24', '1.16', '5.15.5', '5.19.1', '5.19.2', '1.20.1', '8.23',
'2.1', '4.2.1', '8.22.1', '6.16', '1.22', '1.2', '5.16', '3.27',
'6.10.1', '8.2.4', '6.12', '5.15.2', '3.13', '3.1', '3.20', '3.12',
'7.14.2', '5.23.1', '2.4', '5.6', '4.2.3', '8.22.3', '5.15.1',
'7.3', '3', '2.3.1', '3.11', '6.13', '5.15.4', '8.2.1', '1.34.3',
'8.2.2', '5.15.3', '1.17', '4.1.1', '4.1.4', '3.25', '1.20.2',
'8.22.2', '6.9.2', '3.2', '5.5', '5.15.7', '7.12', '8.2.3',
'5.24.1', '1.25', '3.28', '5.9.1', '5.15.6', '8.1.1', '1.10',
'6.11', '3.4', '6.10', '6.9.1', '8.2.5', '5.15', '4.8.2', '8.22',
'5.21', '5.18']

# %% [markdown]
# ### Что же из себя представляет обучающий набор ?

# %%
hack_path = r"E:\Новороссийск" # заменить на свою папку

# %%
train_csv = pd.read_csv(os.path.join(hack_path, "train.csv"), delimiter=',')

# %%
columns = list(train_csv.columns[2:]) #sign1,...,sign8

# %%
stats = []
for index, row in train_csv.iterrows():
    for column in columns:
        if row[column]!=0:
            stats.append(sings_input[row[column] - 1])
statistics = OrderedDict(Counter(stats).most_common())

# %% [markdown]
# #### Визуализируем информацию о частоте знаков в обучающем наборе

# %%
sns.set(rc={'figure.figsize':(21,14)})
sns.barplot(list(statistics.values()), list(statistics.keys()))
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### Набор RSTD отличается по количесту и составу знаков в датасете. Так что следующий вопрос назревает сам собой - какое количество знаков из исходной задачи покрывает наш набор данных ?

# %%
intercestion_signs = list(set(sings_rtsd.values())&set(sings_input))

# %%
print(f"Знаки из набора RTSD составляют {(len(intercestion_signs) / len(sings_input))*100:.1f} % от знаков дорожного движения в нашей задаче")
# Out:
# Знаки из набора RTSD составляют 65.2 % от знаков дорожного движения в нашей задаче

# %% [markdown]
# ##### Как мы убедились выше, у знаков разная частота появления. Предположим, что соотношение знаков в обучающем и тестовом наборе одинаковое. Посмотрим, какой объём train-набора охватывают знаки, которые присутствуют в RTSD.

# %%
coverage_percentage = 0
for name in intercestion_signs:
    coverage_percentage += info[name]
coverage_percentage = coverage_percentage / sum(info.values())

# %%
print(f"Знаки из набора RTSD охватывают {predicted*100:.1f} % от объема всех знаков дорожного движения в train")
# Out:
# Знаки из набора RTSD охватывают 72.4 % от объема всех знаков дорожного движения в train

# %% [markdown]
# Таким образом, мы можем покрыть большую часть кейсов вообще не используя train из нашей задачи.
# По-моему, это 🤡.

# %% [markdown]
# # Пора отправлять решение

# %%
def parse_labeltxt(path):
    with open(os.path.join(path), 'r') as file:
        lines = file.readlines()
        labels = [sings_rtsd[int(x.split(' ')[0])] for x in lines]
        if labels.count('5.19.1')>1:
            labels.append('5.19.2')
        labels = list(set(labels))
        return labels

def rtsd2predict(labels):
    int_labels = []
    for sign in labels:
        if sign in sings_input:
            int_labels.append(sings_input.index(sign) + 1)
    return int_labels

# %%
test_csv = pd.read_csv(os.path.join(hack_path, "test.csv"), delimiter=',')
sample_solution = pd.read_csv(os.path.join(hack_path, "sample_solution.csv"), delimiter=',')
label_path = r"S:\WORK\PROJECTS\yolov5\runs\detect\yolov5m6_signs_test\labels" #заменить на путь, где у вас хранятся запуски yolov5

# %% [markdown]
# #### Преобразуем yolo-label в знаки дорожного движения RTSD, а затем в метки нашей задачи

# %%
predicted_labels = {}
for label in tqdm(os.listdir(label_path)):
    predicted_labels[label[:-3]+'jpg'] = rtsd2predict(parse_labeltxt(os.path.join(label_path, label)))
# Out:
#   0%|          | 0/383 [00:00<?, ?it/s]

# %% [markdown]
# ##### Остался последний шаг. Наш файл с решением должен содержать не названия файлов, а их id, которые мы можем получить из test.csv. Так же учтём, что у нас может быть максимум 8 знаков дорожного движения, то есть наш массив с предсказанием знаков дорожного движения нужно дополнить нулями так, чтобы его длина стала = 8.

# %%
img2id = {}
for index, row in test_csv.iterrows():
    img2id[row['img']] = row['id']

# %%
for img in predicted_final.keys():
    img_id = img2id[img]
    signs = predicted_final[img] + ((8-len(predicted_final[img]))*[0])
    sample_solution[sample_solution['id']==img_id] = [img_id] + signs

# %%
sample_solution.head()
# Out:
#      id  sing1  sing2  sing3  sing4  sing5  sing6  sing7  sing8
# 0   754     22     31      0      0      0      0      0      0
# 1    29      4      5      0      0      0      0      0      0
# 2  1157      8      0      0      0      0      0      0      0
# 3  1049      8      0      0      0      0      0      0      0
# 4   715      8      0      0      0      0      0      0      0

# %%
sample_solution.to_csv(r'S:/solution.csv', index=False)
